# %% [markdown]
# # hydronetworks example
# Quick example notebook to get started with the library.

# %% [markdown]
# ## Basic setup
# ### Imports

# %%
from pathlib import Path

import folium
import matplotlib.pyplot as plt
from rasterio.plot import show as rioshow

from hydronetworks import HydroNetworks

# %% [markdown]
# ### Helper functions

# %%
def plot(vec=None, ras=None, vmin=None, vmax=None, xlim=None, ylim=None):
    fig, ax = plt.subplots(figsize=(3, 6))
    if ras is not None:
        rioshow(ras, cmap="Reds", vmin=vmin, vmax=vmax, ax=ax)
    if vec is not None:
        vec.to_crs(epsg=4326).plot(ax=ax)
    ax.axis("off")
    ax.set_xlim(xlim)
    ax.set_ylim(ylim)
    plt.show()

# %% [markdown]
# ### File paths

# %%
in_path = Path("test_data")
out_path = Path("test_output")

rivers_path = in_path / "rivers.geojson"
dem_path = in_path / "dem.tif"
flow_path = in_path / "flow.tif"
flowacc_path = in_path / "flowacc.tif"

# %%
test_laos_path = Path("data_laos")
rivers_path = test_laos_path / "rivers.geojson"
dem_path = test_laos_path / "dem_laos.tif"
flow_path = test_laos_path / "flow_laos.tif"
flowacc_path = test_laos_path / "flowacc_laos.tif"

# %% [markdown]
# ## Initialize the HydroNetworks object
# And do some quick sanity checks

# %%
net = HydroNetworks(
    rivers_path=rivers_path,
    dem_path=dem_path,
    flow_path=flow_path,
    flowacc_path=flowacc_path,
)

# %%
import geopandas as gpd
from pyproj import CRS
merc = CRS("EPSG:3395")


river = gpd.read_file(rivers_path)
river = river.to_crs(merc)

# %%
def convert_linestring_to_list(geometry):
    if geometry.geom_type == 'LineString':
        return list(geometry.coords)
    return geometry

# river['geometry'] = river['geometry'].apply(convert_linestring_to_list)

# %%
print("DEM")
plot(ras=net.dem, vmin=0, vmax=1000)
# Out:
# DEM

# %%
print("Now let's overlay the rivers")
# plot(ras=net.dem, vec=net.rivers, vmin=0, vmax=500, xlim=(18, 19), ylim=(-34, -33))
plot(ras=net.dem, vec=net.rivers, vmin=0, vmax=500)
# Out:
# Now let's overlay the rivers

# %% [markdown]
# ## Make the rivers network-aware
# These will be the main data structures for holding the river network, and the nodes where rivers join. We'll also add the other data like elevation etc.

# %%
net.rivers['geometry'] = net.rivers['geometry'].apply(convert_linestring_to_list)
# Out:
# C:\Users\lukas\AppData\Local\Temp\ipykernel_32224\1274598247.py:1: UserWarning: Geometry column does not contain geometry.
#   net.rivers['geometry'] = net.rivers['geometry'].apply(convert_linestring_to_list)

# %%
net.rivers['geometry'][4]
# Out:
# [(11794068.133941427, 1556049.105451094),
#  (11794531.96515307, 1555574.236543921),
#  (11794995.796364702, 1555574.236543921)]

# %%
net.create_network()

# %% [markdown]
# Now we have a network of `arcs` (or `edges` if you prefer) and `nodes` from the river network. Each `arc` knows which `nodes` it has at each end (exactly two) and each `node` knows which `arcs` connect to it (at least one, for a source or mouth, and generally two or more).
#
# An example of a single arc, showing its properties. `so` stands for stream-order, which it doesn't have yet!

# %%
def arc_deets(idx):
    labs = ["idx", "fx", "fy", "lx", "ly", "f-node", "l-node", "so", "length"]
    for l, v in zip(labs, net.network[idx].tolist()):
        print(f"{l}: {v}")


def node_deets(idx):
    labs = ["idx", "x", "y", "metadata", "arcs"]
    for l, v in zip(labs, net.nodes[idx][:4] + [net.nodes[idx][4:]]):
        print(f"{l}: {v}")

# %%
arc_deets(0)
# Out:
# idx: 0
# fx: 11807808
# fy: 1556049
# lx: 11805663
# ly: 1557473
# f-node: 0
# l-node: 25
# so: -99
# length: 2574

# %% [markdown]
# So now calculate Shreve stream order for the network. This allows to easily keep track of what is upstream and downstream.

# %%
net.assign_streamorder_iterative(method="shreve")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 net.assign_streamorder_iterative(method="shreve")
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\main.py:142, in HydroNetworks.assign_streamorder_iterative(self, method)
#     140 def assign_streamorder_iterative(self, method="strahler"):
#     141     for node in self.nodes:
# --> 142         sink = self.network[node[4]][0]
#     143         if method == "shreve":
#     144             self.network[sink][7] = shreve_iterative(
#     145                 sink, self.network, self.nodes
#     146             )
#
# IndexError: list index out of range

# %%
net.assign_streamorder(method="shreve")
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 net.assign_streamorder(method="shreve")
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\main.py:131, in HydroNetworks.assign_streamorder(self, method)
#     129 sink = self.network[node[4]][0]
#     130 if method == "shreve":
# --> 131     self.network[sink][7] = shreve(
#     132         sink, self.network[sink][5], self.network, self.nodes
#     133     )
#     134 else:
#     135     self.network[sink][7] = strahler(
#     136         sink, self.network[sink][5], self.network, self.nodes
#     137     )
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:106, in shreve(arc_index, direction_node_id, network, nodes)
#     103 if network[arc][0] != arc_index:
#     104     if network[arc][5] != direction_node_id:
#     105         up_stream_orders.append(
# --> 106             shreve(arc, network[arc][5], network, nodes)
#     107         )
#     108     else:
#     109         up_stream_orders.append(
#     110             shreve(arc, network[arc][6], network, nodes)
#     111         )
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:106, in shreve(arc_index, direction_node_id, network, nodes)
#     103 if network[arc][0] != arc_index:
#     104     if network[arc][5] != direction_node_id:
#     105         up_stream_orders.append(
# --> 106             shreve(arc, network[arc][5], network, nodes)
#     107         )
#     108     else:
#     109         up_stream_orders.append(
#     110             shreve(arc, network[arc][6], network, nodes)
#     111         )
#
#     [... skipping similar frames: shreve at line 106 (118 times)]
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:110, in shreve(arc_index, direction_node_id, network, nodes)
#     105                 up_stream_orders.append(
#     106                     shreve(arc, network[arc][5], network, nodes)
#     107                 )
#     108             else:
#     109                 up_stream_orders.append(
# --> 110                     shreve(arc, network[arc][6], network, nodes)
#     111                 )
#     113 max_orders = heapq.nlargest(2, up_stream_orders)
#     114 if len(max_orders) == 2:
#
#     [... skipping similar frames: shreve at line 106 (1 times)]
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:110, in shreve(arc_index, direction_node_id, network, nodes)
#     105                 up_stream_orders.append(
#     106                     shreve(arc, network[arc][5], network, nodes)
#     107                 )
#     108             else:
#     109                 up_stream_orders.append(
# --> 110                     shreve(arc, network[arc][6], network, nodes)
#     111                 )
#     113 max_orders = heapq.nlargest(2, up_stream_orders)
#     114 if len(max_orders) == 2:
#
#     [... skipping similar frames: shreve at line 110 (1460 times), shreve at line 106 (1345 times)]
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:110, in shreve(arc_index, direction_node_id, network, nodes)
#     105                 up_stream_orders.append(
#     106                     shreve(arc, network[arc][5], network, nodes)
#     107                 )
#     108             else:
#     109                 up_stream_orders.append(
# --> 110                     shreve(arc, network[arc][6], network, nodes)
#     111                 )
#     113 max_orders = heapq.nlargest(2, up_stream_orders)
#     114 if len(max_orders) == 2:
#
#     [... skipping similar frames: shreve at line 106 (41 times)]
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:106, in shreve(arc_index, direction_node_id, network, nodes)
#     103 if network[arc][0] != arc_index:
#     104     if network[arc][5] != direction_node_id:
#     105         up_stream_orders.append(
# --> 106             shreve(arc, network[arc][5], network, nodes)
#     107         )
#     108     else:
#     109         up_stream_orders.append(
#     110             shreve(arc, network[arc][6], network, nodes)
#     111         )
#
# File c:\Users\lukas\OneDrive - Imperial College London\0_Thesis\0relevant_repositories\hydronetworks\hydronetworks\streamorder.py:103, in shreve(arc_index, direction_node_id, network, nodes)
#     101 for index, arc in enumerate(nodes[direction_node_id]):
#     102     if index >= 4:
# --> 103         if network[arc][0] != arc_index:
#     104             if network[arc][5] != direction_node_id:
#     105                 up_stream_orders.append(
#     106                     shreve(arc, network[arc][5], network, nodes)
#     107                 )
#
# RecursionError: maximum recursion depth exceeded in comparison

# %%
arc_deets(10)
# Out:
# idx: 10
# fx: 2070774
# fy: -3941876
# lx: 2074948
# ly: -3950187
# f-node: 25
# l-node: 21
# so: 2
# length: 10754

# %% [markdown]
# Now we have an `so` stream-order! Higher values indicate further down-stream.

# %% [markdown]
# And import elevation, gscd etc for each `node` (note: note into the `arcs`, as their location isn't so well-defined as the `nodes`!)

# %%
net.load_attributes()

# %% [markdown]
# Similarly to the `arcs`, the `nodes` each have a number of attributes:

# %%
node_deets(12)
# Out:
# idx: 12
# x: 2082834
# y: -3951572
# metadata: {'elevation': 101, 'runoff': 41.762306, 'flow_acc': 102}
# arcs: [6]

# %% [markdown]
# Convert to GeoDataFrames

# %%
net.network_to_gdf()

# %% [markdown]
# Now we have `rivers_out` and `nodes_out` that are `GeoDataFrames` and thus a bit easier to work with.

# %%
net.rivers_out.head(2)
# Out:
#    cartodb_id   arcid  up_cells  \
# 0      773011  773011       233
# 1      773386  773386      4101
#
#                                             geometry  idx       xs       ys  \
# 0  MULTILINESTRING ((18.58333 -33.50000, 18.59792...    0  2068687 -3938277
# 1  MULTILINESTRING ((18.62292 -33.63542, 18.62292...    1  2073093 -3956285
#
#         xe       ye  node_start  node_end  so  length
# 0  2070774 -3941876           0        25   1    4357
# 1  2072165 -3962386          11        93  12    7406

# %%
net.nodes_out.head(2)
# Out:
#    idx        x        y  elevation     runoff  flow_acc arcs  \
# 0    0  2068687 -3938277        108   7.435320        27  [0]
# 1    1  2070774 -3941876         88  20.093697       409   []
#
#                      geometry
# 0  POINT (18.58333 -33.49999)
# 1  POINT (18.60208 -33.52708)

# %% [markdown]
# ## Calculate local flow and hydro potential

# %%
net.local_flowacc()
net.calculate_hydro()

# %% [markdown]
# Now we've propagated streamflow down the network, accumulating as we go. The algorithm has also found us some potential hydropower sites!

# %%
net.hydro_points.sample(2)
# Out:
#      arcid  elevation  head  flowrate         power  \
# 95  772750        204    11  0.203264  10951.433983
# 34  773211         83     6  0.146234   4297.522350
#
#                       geometry
# 95  POINT (18.83589 -33.40577)
# 34  POINT (18.69899 -33.59267)

# %% [markdown]
# ## Let's see our river on a map!

# %%
hp = net.hydro_points.groupby("arcid").mean()
riv = net.rivers_out.join(other=hp, how="left", on="arcid", rsuffix="_hp")
riv = riv[["so", "flowrate", "geometry"]]
riv.flowrate = riv.flowrate.round(2)

# %%
m = folium.Map(location=(-33.7, 18.5), zoom_start=10)  # lat, lon
folium.GeoJson(
    riv,
    style_function=lambda ft: {"weight": 2 * ft["properties"]["so"] ** 0.5},
    tooltip=folium.GeoJsonTooltip(
        fields=["so", "flowrate"], aliases=["Streamorder", "Flowrate (m3/s)"]
    ),
).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## And save the output files

# %%
net.rivers_out.to_file(out_path / "arcs.geojson", driver="GeoJSON")
net.nodes_out.drop("arcs", axis=1).to_file(out_path / "nodes.geojson", driver="GeoJSON")
net.hydro_points.to_file(out_path / "hydro.geojson", driver="GeoJSON")
